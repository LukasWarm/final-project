# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_row', 1000)
import numpy as np

# %%
#import pandas_profiling
#pip install -U pandas-profiling
/Users/hpb/PycharmProjects/Ironhack/Final Project/Climbing results 2018:19

# %%
df_boulder=pd.read_csv('/Users/hpb/PycharmProjects/Ironhack/Final Project/Climbing results 2018:19/boulder_results.csv')
df_lead =pd.read_csv('/Users/hpb/PycharmProjects/Ironhack/Final Project/Climbing results 2018:19/lead_results.csv')

# %% [markdown]
# ### Exploring data

# %%
df_boulder.head()
# Out:
#                                    Competition Title         Competition Date  \
# 0  European Youth Championships (B) - Brixen (ITA...  20  - 22 September 2019
# 1  European Youth Championships (B) - Brixen (ITA...  20  - 22 September 2019
# 2  European Youth Championships (B) - Brixen (ITA...  20  - 22 September 2019
# 3  European Youth Championships (B) - Brixen (ITA...  20  - 22 September 2019
# 4  European Youth Championships (B) - Brixen (ITA...  20  - 22 September 2019
#
#     FIRST        LAST Nation  StartNr  Rank Qualification Qualification 1  \
# 0   Naile     MEIGNAN    FRA     15.0     1        6T7z99             NaN
# 1  Miriam        FOGU    ITA     27.0     2       4T8z814             NaN
# 2   Vanda  MICHALKOVA    SVK     48.0     3        6T7z89             NaN
# 3    Lola     SAUTIER    FRA     17.0     4        4T6z69             NaN
# 4  Polina    KULAGINA    RUS     39.0     5       4T6z611             NaN
#
#   Qualification 2 Semifinal   Final Category
# ...

# %%
df_lead.head()
# Out:
#                                    Competition Title     Competition Date  \
# 0  European Championship (L,S) - Edinburgh (GBR) ...  4  - 6 October 2019
# 1  European Championship (L,S) - Edinburgh (GBR) ...  4  - 6 October 2019
# 2  European Championship (L,S) - Edinburgh (GBR) ...  4  - 6 October 2019
# 3  European Championship (L,S) - Edinburgh (GBR) ...  4  - 6 October 2019
# 4  European Championship (L,S) - Edinburgh (GBR) ...  4  - 6 October 2019
#
#      FIRST      LAST Nation  StartNr  Rank Qualification  \
# 0    Lucka   RAKOVEC    SLO    222.0     1           NaN
# 1    Laura    ROGORA    ITA    234.0     2           NaN
# 2     Luce    DOUADY    FRA    229.0     3           NaN
# 3     Mina  MARKOVIC    SLO    237.0     4           NaN
# 4  Jessica      PILZ    AUT    213.0     5           NaN
#
#                Qualification 1              Qualification 2 Semifinal Final  \
# 0      50+1.,50+1.,50+1.,50+1.      44 2.,44 2.,44 2.,44 2.        39   46+
# ...

# %%
df_boulder['Competition Title'].value_counts()
# Out:
# IFSC Youth World Championships -  Arco (ITA) 2019                    944
# IFSC Youth World Championships -  Moscow (RUS) 2018                  802
# European Youth Cup (B) - Graz (AUT) 2019                             656
# European Youth Championships (B) - Brussels (BEL) 2018               602
# European Youth Championships (B) - Brixen (ITA) 2019                 564
# European Youth Cup (B) - Graz (AUT) 2018                             550
# European Youth Cup (B) - Sofia (BUL) 2019                            516
# European Youth Cup (B) - Soure (POR) 2019                            482
# European Youth Cup (B) - Delft (NED) 2018                            422
# European Youth Cup (B) - Sofia (BUL) 2018                            386
# European Youth Cup (B) - Soure (POR) 2018                            318
# Asian Youth Championships - Chongqing (CHN) 2018                     302
# IFSC Climbing World Championships - Innsbruck (AUT) 2018             262
# ...

# %%
df_lead['Competition Title'].value_counts()
# Out:
# IFSC Youth World Championships -  Arco (ITA) 2019                    868
# IFSC Youth World Championships -  Moscow (RUS) 2018                  778
# European Youth Cup (S,L) - Imst (AUT) 2019                           604
# European Youth Championship (L, S) - Imst 2018                       564
# European Youth Cup (L) - Munich (GER) 2018                           456
# European Youth Cup (L) - St. Pierre Faucigny (FRA) 2019              452
# IFSC Climbing World Championships - Innsbruck (AUT) 2018             450
# IFSC Climbing Worldcup (L, S) - Chamonix (FRA) 2019                  428
# European Youth Cup (L) - Ostermundigen (SUI) 2019                    426
# IFSC Climbing Worldcup (L,S) - Chamonix (FRA) 2018                   406
# IFSC Climbing World Championships - Hachioji (JPN) 2019              382
# IFSC Climbing Worldcup (L, S) - Villars (SUI) 2019                   366
# European Youth Cup (L,S) - Voiron (FRA) 2018                         362
# ...

# %% [markdown]
# ### Sorting Columns

# %%
df_boulder =df_boulder.rename(columns={column:column.upper().replace(" ", "_") for column in df_boulder.columns})

# %%
df_lead =df_lead.rename(columns={column:column.upper().replace(" ", "_") for column in df_lead.columns})

# %%
df_lead[['COMP','PLACE']] = df_lead['COMPETITION_TITLE'].str.split('\s+-\s+', expand=True)
df_lead['LOCATION'] = df_lead['PLACE'].str.extract('([A-Z]\w{0,})', expand=True)
df_lead['YEAR'] = df_lead['PLACE'].str.extract('(\d\d\d\d)', expand=True)
df_lead['COUNTRY'] = df_lead['PLACE'].str.extract('(\w*[A-Z]\w*[A-Z]\w*)', expand=True)

# %%
df_lead.columns
cols = ['COMP','PLACE', 'LOCATION', 'YEAR', 'COUNTRY', 'COMPETITION_TITLE', 'COMPETITION_DATE', 'FIRST', 'LAST', 'NATION',
       'STARTNR', 'RANK', 'QUALIFICATION', 'QUALIFICATION_1',
       'QUALIFICATION_2', 'SEMIFINAL', 'FINAL', 'POINTS', 'CATEGORY']

# %%
df_lead = df_lead[cols]

# %%
df_boulder[['COMP','PLACE']] = df_boulder['COMPETITION_TITLE'].str.split('\s+-\s+', expand=True)
df_boulder['LOCATION'] = df_boulder['PLACE'].str.extract('([A-Z]\w{0,})', expand=True)
df_boulder['YEAR'] = df_boulder['PLACE'].str.extract('(\d\d\d\d)', expand=True)
df_boulder['COUNTRY'] = df_boulder['PLACE'].str.extract('(\w*[A-Z]\w*[A-Z]\w*)', expand=True)

# %%
df_boulder.columns
cols=['COMP', 'PLACE',
       'LOCATION', 'YEAR', 'COUNTRY','COMPETITION_TITLE', 'COMPETITION_DATE', 'FIRST', 'LAST', 'NATION',
       'STARTNR', 'RANK', 'QUALIFICATION', 'QUALIFICATION_1',
       'QUALIFICATION_2', 'SEMIFINAL', 'FINAL', 'CATEGORY']

# %%
df_boulder = df_boulder[cols]

# %% [markdown]
# ### Cleaning empty spaces from data & null values

# %%
df_lead['YEAR'] = df_lead['YEAR'].str.replace(" ","")

# %%
df_lead['YEAR'] = df_lead['YEAR'].apply(np.int64)

# %%
df_lead['QUALIFICATION'].isna().sum()
# Out:
# 9282

# %%
df_lead['QUALIFICATION_1'].value_counts()
# Out:
# Top1.,Top1.,Top1.,Top1.,Top1.,Top1.,Top1.,Top1.                                                                    267
# Top1.,Top1.,Top1.,Top1.                                                                                            267
# 20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.                                                             39
# 20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.,20+39.     39
# 12+16.,12+16.,12+16.,12+16.,12+16.,12+16.,12+16.,12+16.                                                             30
#                                                                                                                   ...
# 21.5+27.,21.5+27.,21.5+27.,21.5+27.,21.5+27.,21.5+27.,21.5+27.,21.5+27.                                              1
# 17 90.,17 90.,17 90.,17 90.                                                                                          1
# ...

# %%
df_lead['QUALIFICATION'].fillna(0, inplace=True)
df_lead['FINAL'].fillna(0, inplace=True)
df_lead['SEMIFINAL'].fillna(0, inplace=True)
df_lead['QUALIFICATION_1'].fillna(0, inplace=True)
df_lead['QUALIFICATION_2'].fillna(0, inplace=True)
df_lead['POINTS'].fillna(0, inplace=True)

# %%
df_boulder.columns
# Out:
# Index(['COMP', 'PLACE', 'LOCATION', 'YEAR', 'COUNTRY', 'COMPETITION_TITLE',
#        'COMPETITION_DATE', 'FIRST', 'LAST', 'NATION', 'STARTNR', 'RANK',
#        'QUALIFICATION', 'QUALIFICATION_1', 'QUALIFICATION_2', 'SEMIFINAL',
#        'FINAL', 'CATEGORY'],
#       dtype='object')

# %%
df_boulder['FINAL'].fillna(0, inplace=True)
df_boulder['SEMIFINAL'].fillna(0, inplace=True)
df_boulder['QUALIFICATION'].fillna(0, inplace=True)
df_boulder['QUALIFICATION_1'].fillna(0, inplace=True)
df_boulder['QUALIFICATION_2'].fillna(0, inplace=True)

# %%
df_boulder['YEAR'] = df_boulder['YEAR'].str.replace(" ","")

# %%
df_boulder['YEAR'] = df_boulder['YEAR'].apply(np.int64)

# %%
df_boulder['YEAR'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### Preparing data for concat with athletes data

# %%
df_boulder["NAME"] = df_boulder["FIRST"] + df_boulder["LAST"]

# %%
for key, value in df_boulder["NAME"].iteritems():
    value = value.strip()

# %%
df_boulder["NAME"].value_counts()
# Out:
# FlavyCOHAUT                            26
# NicolaiUZNIK                           25
# AlbertoGINÉS LÓPEZ                     25
# MatteaPÖTZI                            24
# MiriamFOGU                             23
#                                        ..
# Muhammad TaqiuddinBIN MOHD ZULKIFLI     1
# JurijsKRASANOVS                         1
# MyrtoPETALIDOU                          1
# JeongranKO                              1
# AlejandroCRESPO COBOS                   1
# Name: NAME, Length: 1840, dtype: int64

# %%
df_boulder.duplicated().mean()*100
# Out:
# 33.58998049481573

# %%
df_boulder= df_boulder.drop_duplicates()

# %%
df_boulder.reset_index(drop=True)
# Out:
#                                   COMP                 PLACE LOCATION  YEAR  \
# 0     European Youth Championships (B)     Brixen (ITA) 2019   Brixen  2019
# 1     European Youth Championships (B)     Brixen (ITA) 2019   Brixen  2019
# 2     European Youth Championships (B)     Brixen (ITA) 2019   Brixen  2019
# 3     European Youth Championships (B)     Brixen (ITA) 2019   Brixen  2019
# 4     European Youth Championships (B)     Brixen (ITA) 2019   Brixen  2019
# ...                                ...                   ...      ...   ...
# 6464                      Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 6465                      Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 6466                      Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 6467                      Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 6468                      Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
#
# ...

# %%
boulder_results = df_boulder[df_boulder.COMPETITION_TITLE.str.contains('cup|Worldcup|World', case=False)]
#separating Wolrd cups & championships only.

# %%
boulder_results.reset_index(drop=True)
# Out:
#                                 COMP                 PLACE LOCATION  YEAR  \
# 0     IFSC Youth World Championships      Arco (ITA) 2019      Arco  2019
# 1     IFSC Youth World Championships      Arco (ITA) 2019      Arco  2019
# 2     IFSC Youth World Championships      Arco (ITA) 2019      Arco  2019
# 3     IFSC Youth World Championships      Arco (ITA) 2019      Arco  2019
# 4     IFSC Youth World Championships      Arco (ITA) 2019      Arco  2019
# ...                              ...                   ...      ...   ...
# 5497                    Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 5498                    Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 5499                    Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 5500                    Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
# 5501                    Asia Cup (B)  Hong Kong (HKG) 2018     Hong  2018
#
#      COUNTRY                                  COMPETITION_TITLE  \
# ...

# %%
boulder_results.isna().sum()
# Out:
# COMP                   0
# PLACE                  0
# LOCATION               0
# YEAR                   0
# COUNTRY                0
# COMPETITION_TITLE      0
# COMPETITION_DATE       0
# FIRST                  0
# LAST                   0
# NATION                 0
# STARTNR              208
# RANK                   0
# QUALIFICATION          0
# QUALIFICATION_1        0
# QUALIFICATION_2        0
# SEMIFINAL              0
# FINAL                  0
# CATEGORY               0
# NAME                   0
# dtype: int64

# %%
boulder_results['STARTNR']=boulder_results['STARTNR'].fillna(0)
# Out:
# <ipython-input-45-505170077571>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boulder_results['STARTNR']=boulder_results['STARTNR'].fillna(0)

# %%
boulder_results['STARTNR'].isna().mean()*100
# Out:
# 0.0

# %%
#separate youth results
youth_boulder= boulder_results[boulder_results.COMPETITION_TITLE.str.contains('Youth', case=False)]

# %%
youth_boulder.reset_index(drop=True)
# Out:
#                                 COMP             PLACE LOCATION  YEAR COUNTRY  \
# 0     IFSC Youth World Championships  Arco (ITA) 2019      Arco  2019     ITA
# 1     IFSC Youth World Championships  Arco (ITA) 2019      Arco  2019     ITA
# 2     IFSC Youth World Championships  Arco (ITA) 2019      Arco  2019     ITA
# 3     IFSC Youth World Championships  Arco (ITA) 2019      Arco  2019     ITA
# 4     IFSC Youth World Championships  Arco (ITA) 2019      Arco  2019     ITA
# ...                              ...               ...      ...   ...     ...
# 2533          European Youth Cup (B)  Graz (AUT) 2018      Graz  2018     AUT
# 2534          European Youth Cup (B)  Graz (AUT) 2018      Graz  2018     AUT
# 2535          European Youth Cup (B)  Graz (AUT) 2018      Graz  2018     AUT
# 2536          European Youth Cup (B)  Graz (AUT) 2018      Graz  2018     AUT
# 2537          European Youth Cup (B)  Graz (AUT) 2018      Graz  2018     AUT
#
# ...

# %%
youth_boulder.duplicated().mean()*100
# Out:
# 0.0

# %%
youth_boulder.isna().mean()*100
# Out:
# COMP                 0.0
# PLACE                0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST                0.0
# LAST                 0.0
# NATION               0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# CATEGORY             0.0
# NAME                 0.0
# dtype: float64

# %%
#separate adult results
adult_boulder_results = boulder_results[~boulder_results.COMPETITION_TITLE.str.contains('Youth', case=False)]

# %%
adult_boulder_results.reset_index(drop=True)
# Out:
#                                    COMP                 PLACE  LOCATION  YEAR  \
# 0     IFSC Climbing World Championships   Hachioji (JPN) 2019  Hachioji  2019
# 1     IFSC Climbing World Championships   Hachioji (JPN) 2019  Hachioji  2019
# 2     IFSC Climbing World Championships   Hachioji (JPN) 2019  Hachioji  2019
# 3     IFSC Climbing World Championships   Hachioji (JPN) 2019  Hachioji  2019
# 4     IFSC Climbing World Championships   Hachioji (JPN) 2019  Hachioji  2019
# ...                                 ...                   ...       ...   ...
# 2959                       Asia Cup (B)  Hong Kong (HKG) 2018      Hong  2018
# 2960                       Asia Cup (B)  Hong Kong (HKG) 2018      Hong  2018
# 2961                       Asia Cup (B)  Hong Kong (HKG) 2018      Hong  2018
# 2962                       Asia Cup (B)  Hong Kong (HKG) 2018      Hong  2018
# 2963                       Asia Cup (B)  Hong Kong (HKG) 2018      Hong  2018
#
# ...

# %%
adult_boulder_results.duplicated().mean()*100
# Out:
# 0.0

# %%
adult_boulder_results.isna().mean()*100
# Out:
# COMP                 0.0
# PLACE                0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST                0.0
# LAST                 0.0
# NATION               0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# CATEGORY             0.0
# NAME                 0.0
# dtype: float64

# %%
df_lead["NAME"] = df_lead["FIRST"] + df_lead["LAST"]

# %%
for key, value in df_lead['NAME'].iteritems():
    value = value.strip()

# %%
df_lead['NAME'].value_counts()
# Out:
# MykhayilTKACHUK                 37
# LauraROGORA                     33
# AlbertoGINÉS LÓPEZ              33
# Mikel AsierLINACISORO MOLINA    32
# JakubKONECNY                    32
#                                 ..
# TaiTEWKESBURY                    2
# KharismaRAGIL RAKASIWI           2
# NikolaKRAMARIC                   1
# VeronikaSCHEUEROVA               1
# SergeiLUZHETSKII                 1
# Name: NAME, Length: 1467, dtype: int64

# %%
df_lead= df_lead.drop_duplicates()

# %%
df_lead.reset_index(drop=True)
# Out:
#                              COMP                 PLACE   LOCATION  YEAR  \
# 0     European Championship (L,S)  Edinburgh (GBR) 2019  Edinburgh  2019
# 1     European Championship (L,S)  Edinburgh (GBR) 2019  Edinburgh  2019
# 2     European Championship (L,S)  Edinburgh (GBR) 2019  Edinburgh  2019
# 3     European Championship (L,S)  Edinburgh (GBR) 2019  Edinburgh  2019
# 4     European Championship (L,S)  Edinburgh (GBR) 2019  Edinburgh  2019
# ...                           ...                   ...        ...   ...
# 9925     European Youth Cup (L,S)    Voiron (FRA) 2018      Voiron  2018
# 9926     European Youth Cup (L,S)    Voiron (FRA) 2018      Voiron  2018
# 9927     European Youth Cup (L,S)    Voiron (FRA) 2018      Voiron  2018
# 9928     European Youth Cup (L,S)    Voiron (FRA) 2018      Voiron  2018
# 9929     European Youth Cup (L,S)    Voiron (FRA) 2018      Voiron  2018
#
#      COUNTRY                                  COMPETITION_TITLE  \
# ...

# %%
lead_results = df_lead[df_lead.COMPETITION_TITLE.str.contains('cup|Worldcup|World', case=False)]

# %%
lead_results.reset_index(drop=True)
# Out:
#                             COMP               PLACE LOCATION  YEAR COUNTRY  \
# 0     IFSC Climbing Worldcup (L)   Kranj (SLO) 2019     Kranj  2019     SLO
# 1     IFSC Climbing Worldcup (L)   Kranj (SLO) 2019     Kranj  2019     SLO
# 2     IFSC Climbing Worldcup (L)   Kranj (SLO) 2019     Kranj  2019     SLO
# 3     IFSC Climbing Worldcup (L)   Kranj (SLO) 2019     Kranj  2019     SLO
# 4     IFSC Climbing Worldcup (L)   Kranj (SLO) 2019     Kranj  2019     SLO
# ...                          ...                 ...      ...   ...     ...
# 8711    European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018     FRA
# 8712    European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018     FRA
# 8713    European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018     FRA
# 8714    European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018     FRA
# 8715    European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018     FRA
#
# ...

# %%
lead_results.isna().sum()
# Out:
# COMP                   0
# PLACE                  0
# LOCATION               0
# YEAR                   0
# COUNTRY                0
# COMPETITION_TITLE      0
# COMPETITION_DATE       0
# FIRST                  0
# LAST                   0
# NATION                 0
# STARTNR              450
# RANK                   0
# QUALIFICATION          0
# QUALIFICATION_1        0
# QUALIFICATION_2        0
# SEMIFINAL              0
# FINAL                  0
# POINTS                 0
# CATEGORY               0
# NAME                   0
# dtype: int64

# %%
lead_results['STARTNR']=lead_results['STARTNR'].fillna(0)
# Out:
# <ipython-input-63-905c9ddd7c38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lead_results['STARTNR']=lead_results['STARTNR'].fillna(0)

# %%
lead_results.isna().sum()*100
# Out:
# COMP                 0
# PLACE                0
# LOCATION             0
# YEAR                 0
# COUNTRY              0
# COMPETITION_TITLE    0
# COMPETITION_DATE     0
# FIRST                0
# LAST                 0
# NATION               0
# STARTNR              0
# RANK                 0
# QUALIFICATION        0
# QUALIFICATION_1      0
# QUALIFICATION_2      0
# SEMIFINAL            0
# FINAL                0
# POINTS               0
# CATEGORY             0
# NAME                 0
# dtype: int64

# %%
youth_lead= lead_results[lead_results.COMPETITION_TITLE.str.contains('Youth', case=False)]

# %%
youth_lead.reset_index(drop=True)
# Out:
#                                 COMP               PLACE LOCATION  YEAR  \
# 0     IFSC Youth World Championships    Arco (ITA) 2019      Arco  2019
# 1     IFSC Youth World Championships    Arco (ITA) 2019      Arco  2019
# 2     IFSC Youth World Championships    Arco (ITA) 2019      Arco  2019
# 3     IFSC Youth World Championships    Arco (ITA) 2019      Arco  2019
# 4     IFSC Youth World Championships    Arco (ITA) 2019      Arco  2019
# ...                              ...                 ...      ...   ...
# 4655        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018
# 4656        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018
# 4657        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018
# 4658        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018
# 4659        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018
#
#      COUNTRY                                  COMPETITION_TITLE  \
# ...

# %%
adult_lead_results = lead_results[~lead_results.COMPETITION_TITLE.str.contains('Youth', case=False)]

# %%
adult_lead_results.reset_index(drop=True)
# Out:
#                               COMP                PLACE LOCATION  YEAR  \
# 0       IFSC Climbing Worldcup (L)    Kranj (SLO) 2019     Kranj  2019
# 1       IFSC Climbing Worldcup (L)    Kranj (SLO) 2019     Kranj  2019
# 2       IFSC Climbing Worldcup (L)    Kranj (SLO) 2019     Kranj  2019
# 3       IFSC Climbing Worldcup (L)    Kranj (SLO) 2019     Kranj  2019
# 4       IFSC Climbing Worldcup (L)    Kranj (SLO) 2019     Kranj  2019
# ...                            ...                  ...      ...   ...
# 4051  IFSC Climbing Worldcup (L,S)  Villars (SUI) 2018   Villars  2018
# 4052  IFSC Climbing Worldcup (L,S)  Villars (SUI) 2018   Villars  2018
# 4053  IFSC Climbing Worldcup (L,S)  Villars (SUI) 2018   Villars  2018
# 4054  IFSC Climbing Worldcup (L,S)  Villars (SUI) 2018   Villars  2018
# 4055  IFSC Climbing Worldcup (L,S)  Villars (SUI) 2018   Villars  2018
#
#      COUNTRY                                  COMPETITION_TITLE  \
# ...

# %%
adult_lead_results.isna().mean()*100
# Out:
# COMP                 0.0
# PLACE                0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST                0.0
# LAST                 0.0
# NATION               0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# POINTS               0.0
# CATEGORY             0.0
# NAME                 0.0
# dtype: float64

# %%
adult_lead_results.duplicated().mean()*100
# Out:
# 0.0

# %% [markdown]
# # Bringing in athletes data

# %%
df_ages=pd.read_csv('/Users/hpb/PycharmProjects/Ironhack/Final Project/all_ages.csv')

# %%
df_ages.head()
# Out:
#    climber_id      LAST        FIRST  Gender Nation Last_active     YOB
# 0        6367  Klingler        Petra  female    SUI  01/03/2020  1992.0
# 1        6457    Choong    Katherine  female    SUI  01/03/2020  1992.0
# 2        9979    Koller  Anne-Sophie  female    SUI  01/03/2020  1996.0
# 3       10326      Vogt      Dimitri    male    SUI  01/03/2020  1997.0
# 4       10328     Kümin       Andrea  female    SUI  01/03/2020  1997.0

# %%
df_ages = df_ages.drop_duplicates()

# %%
df_ages.reset_index(drop=True)
# Out:
#        climber_id          LAST         FIRST  Gender Nation Last_active  \
# 0            6367      Klingler         Petra  female    SUI  01/03/2020
# 1            6457        Choong     Katherine  female    SUI  01/03/2020
# 2            9979        Koller   Anne-Sophie  female    SUI  01/03/2020
# 3           10326          Vogt       Dimitri    male    SUI  01/03/2020
# 4           10328         Kümin        Andrea  female    SUI  01/03/2020
# ...           ...           ...           ...     ...    ...         ...
# 12868       81868   LOW SU YING  Stefanie Ann  female    SGP         NaN
# 12869       81869  SALLSABILLAH       Rajiah   female    INA         NaN
# 12870       81870       PETROVA      Kseniia   female    RUS         NaN
# 12871       81871      MUHAMMAD       Hinayah    male    INA         NaN
# 12872       81872        RAHEMI       Melika   female    IRI         NaN
#
#           YOB
# 0      1992.0
# 1      1992.0
# 2      1996.0
# 3      1997.0
# ...

# %%
df_ages['LAST'] = df_ages['LAST'].str.upper()

# %%
df_ages['LAST'].str.replace(" ","")
#lots of hidden white spaces in this dataset. Remove any columns you need/going to use.
# Out:
# 0            KLINGLER
# 1              CHOONG
# 2              KOLLER
# 3                VOGT
# 4               KÜMIN
#              ...
# 12868       LOWSUYING
# 12869    SALLSABILLAH
# 12870         PETROVA
# 12871        MUHAMMAD
# 12872          RAHEMI
# Name: LAST, Length: 12873, dtype: object

# %%
df_ages['YOB'].isna().sum()
#lots of nulls but can be sorted later with the youth dataset.
# Out:
# 4312

# %%
df_ages.dtypes
# Out:
# climber_id       int64
# LAST            object
# FIRST           object
# Gender          object
# Nation          object
# Last_active     object
# YOB            float64
# dtype: object

# %%
df_ages['LAST'].isna().sum()
# Out:
# 3

# %%
df_ages = df_ages[df_ages['LAST'].notna()]

# %%
df_ages.reset_index(drop=True)
# Out:
#        climber_id          LAST         FIRST  Gender Nation Last_active  \
# 0            6367      KLINGLER         Petra  female    SUI  01/03/2020
# 1            6457        CHOONG     Katherine  female    SUI  01/03/2020
# 2            9979        KOLLER   Anne-Sophie  female    SUI  01/03/2020
# 3           10326          VOGT       Dimitri    male    SUI  01/03/2020
# 4           10328         KÜMIN        Andrea  female    SUI  01/03/2020
# ...           ...           ...           ...     ...    ...         ...
# 12865       81868   LOW SU YING  Stefanie Ann  female    SGP         NaN
# 12866       81869  SALLSABILLAH       Rajiah   female    INA         NaN
# 12867       81870       PETROVA      Kseniia   female    RUS         NaN
# 12868       81871      MUHAMMAD       Hinayah    male    INA         NaN
# 12869       81872        RAHEMI       Melika   female    IRI         NaN
#
#           YOB
# 0      1992.0
# 1      1992.0
# 2      1996.0
# 3      1997.0
# ...

# %%
#A lot of empty spaces that are causing join issues.
for key, value in df_ages['LAST'].iteritems():
    value = value.strip()

# %%
df_ages =df_ages.rename(columns={column:column.upper().replace(" ", "_") for column in df_ages.columns})

# %%
df_ages["NAME"] = df_ages["FIRST"].astype(str) + df_ages["LAST"]

# %%
df_ages
# Out:
#        CLIMBER_ID          LAST         FIRST  GENDER NATION LAST_ACTIVE  \
# 0            6367      KLINGLER         Petra  female    SUI  01/03/2020
# 1            6457        CHOONG     Katherine  female    SUI  01/03/2020
# 2            9979        KOLLER   Anne-Sophie  female    SUI  01/03/2020
# 3           10326          VOGT       Dimitri    male    SUI  01/03/2020
# 4           10328         KÜMIN        Andrea  female    SUI  01/03/2020
# ...           ...           ...           ...     ...    ...         ...
# 12868       81868   LOW SU YING  Stefanie Ann  female    SGP         NaN
# 12869       81869  SALLSABILLAH       Rajiah   female    INA         NaN
# 12870       81870       PETROVA      Kseniia   female    RUS         NaN
# 12871       81871      MUHAMMAD       Hinayah    male    INA         NaN
# 12872       81872        RAHEMI       Melika   female    IRI         NaN
#
#           YOB                      NAME
# 0      1992.0             PetraKLINGLER
# ...

# %%
for key, value in df_ages['NAME'].iteritems():
    value = value.strip()

# %%
for key, value in df_ages['YOB'].iteritems():
    print(value, type)
# Out:
# 1992.0 <class 'type'>
# 1992.0 <class 'type'>
# 1996.0 <class 'type'>
# 1997.0 <class 'type'>
# 1997.0 <class 'type'>
# 1998.0 <class 'type'>
# 1999.0 <class 'type'>
# 1998.0 <class 'type'>
# 2000.0 <class 'type'>
# 2000.0 <class 'type'>
# 2003.0 <class 'type'>
# 2004.0 <class 'type'>
# 2003.0 <class 'type'>
# 2002.0 <class 'type'>
# 2001.0 <class 'type'>
# 2003.0 <class 'type'>
# 2003.0 <class 'type'>
# 2004.0 <class 'type'>
# 2001.0 <class 'type'>
# 2001.0 <class 'type'>
# 2004.0 <class 'type'>
# 2005.0 <class 'type'>
# 2003.0 <class 'type'>
# 2004.0 <class 'type'>
# 2003.0 <class 'type'>
# 2003.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2003.0 <class 'type'>
# 2001.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2004.0 <class 'type'>
# 2005.0 <class 'type'>
# 2004.0 <class 'type'>
# 2005.0 <class 'type'>
# ...

# %%
df_ages.isna().mean()*100
# Out:
# CLIMBER_ID      0.000000
# LAST            0.000000
# FIRST           0.023310
# GENDER          1.950272
# NATION          0.000000
# LAST_ACTIVE     4.335664
# YOB            33.480963
# NAME            0.000000
# dtype: float64

# %%
for key, value in df_ages['NAME'].iteritems():
    value = value.strip()

# %% [markdown]
# ## Concat with Boulder Results

# %%
youth_boulder['CATEGORY'].value_counts()
# Out:
# boulder    2538
# Name: CATEGORY, dtype: int64

# %%
youth_boulder['NAME']
# Out:
# 373                    LuceDOUADY
# 374                 NatsumiHIRANO
# 375                   SakiKIKUCHI
# 376                  NaileMEIGNAN
# 377                      HanaKUDO
#                   ...
# 5974                 TomášLUKÁŠEK
# 5975           Felix StåhlWADSTEN
# 5976            Hauk SteinssonLEM
# 5977    Christian PhillipELIASSEN
# 5978                JanMACHARACEK
# Name: NAME, Length: 2538, dtype: object

# %%
result = pd.merge(youth_boulder, df_ages, how='outer', on='NAME')

# %%
youth_boulder = result

# %%
youth_boulder
# Out:
#                                  COMP              PLACE LOCATION    YEAR  \
# 0      IFSC Youth World Championships   Arco (ITA) 2019      Arco  2019.0
# 1              European Youth Cup (B)   Soure (POR) 2019    Soure  2019.0
# 2      IFSC Youth World Championships  Moscow (RUS) 2018   Moscow  2018.0
# 3              European Youth Cup (B)  Sofia (BUL) 2018     Sofia  2018.0
# 4              European Youth Cup (B)  Soure (POR) 2018     Soure  2018.0
# ...                               ...                ...      ...     ...
# 14776                             NaN                NaN      NaN     NaN
# 14777                             NaN                NaN      NaN     NaN
# 14778                             NaN                NaN      NaN     NaN
# 14779                             NaN                NaN      NaN     NaN
# 14780                             NaN                NaN      NaN     NaN
#
#       COUNTRY                                  COMPETITION_TITLE  \
# ...

# %%
import random 
nans = youth_boulder['YOB'].isna()
length = sum(nans)
replacement = random.choices([2002, 2003, 2004, 2000], k=length)
youth_boulder.loc[nans,'YOB'] = replacement

# %%
youth_boulder['YOB'] = youth_boulder['YOB'].apply(np.int64)

# %%
youth_boulder['YOB'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ## Deleting athletes that didn't compete

# %%
youth_boulder['GENDER'].fillna("Unknown", inplace=True)
youth_boulder['STARTNR'].fillna(0, inplace=True)

# %%
youth_boulder.drop(['CLIMBER_ID', 'LAST_y', 'FIRST_y','LAST_ACTIVE', 'PLACE'], axis=1, inplace=True)

# %%
youth_boulder['GENDER'].fillna("Unknown", inplace=True)
youth_boulder['NATION_y'].fillna("Unknown", inplace=True)
youth_boulder['STARTNR'].fillna(0, inplace=True)

# %%
youth_boulder.isna().mean()*100
# Out:
# COMP                 82.727826
# LOCATION             82.727826
# YEAR                 82.727826
# COUNTRY              82.727826
# COMPETITION_TITLE    82.727826
# COMPETITION_DATE     82.727826
# FIRST_x              82.727826
# LAST_x               82.727826
# NATION_x             82.727826
# STARTNR               0.000000
# RANK                 82.727826
# QUALIFICATION        82.727826
# QUALIFICATION_1      82.727826
# QUALIFICATION_2      82.727826
# SEMIFINAL            82.727826
# FINAL                82.727826
# CATEGORY             82.727826
# NAME                  0.000000
# GENDER                0.000000
# NATION_y              0.000000
# YOB                   0.000000
# dtype: float64

# %%
youth_boulder = youth_boulder[youth_boulder['COMPETITION_TITLE'].notna()]

# %%
youth_boulder.isna().mean()*100
# Out:
# COMP                 0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST_x              0.0
# LAST_x               0.0
# NATION_x             0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# CATEGORY             0.0
# NAME                 0.0
# GENDER               0.0
# NATION_y             0.0
# YOB                  0.0
# dtype: float64

# %%
youth_boulder.to_csv(r'youth_boulder.csv', index = False)

# %%
adult_boulder_results.isna().mean()*100
# Out:
# COMP                 0.0
# PLACE                0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST                0.0
# LAST                 0.0
# NATION               0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# CATEGORY             0.0
# NAME                 0.0
# dtype: float64

# %%
adult_boulder = pd.merge(adult_boulder_results, df_ages, how='outer', on='NAME')

# %%
adult_boulder.isna().mean()*100
# Out:
# COMP                 79.817649
# PLACE                79.817649
# LOCATION             79.817649
# YEAR                 79.817649
# COUNTRY              79.817649
# COMPETITION_TITLE    79.817649
# COMPETITION_DATE     79.817649
# FIRST_x              79.817649
# LAST_x               79.817649
# NATION_x             79.817649
# STARTNR              79.817649
# RANK                 79.817649
# QUALIFICATION        79.817649
# QUALIFICATION_1      79.817649
# QUALIFICATION_2      79.817649
# SEMIFINAL            79.817649
# FINAL                79.817649
# CATEGORY             79.817649
# NAME                  0.000000
# CLIMBER_ID            2.709215
# LAST_y                2.709215
# FIRST_y               2.728753
# GENDER                4.343862
# NATION_y              2.709215
# LAST_ACTIVE           6.792576
# YOB                  30.771736
# dtype: float64

# %%
adult_boulder = adult_boulder[adult_boulder['COMPETITION_TITLE'].notna()]

# %%
adult_boulder.isna().mean()*100
# Out:
# COMP                  0.000000
# PLACE                 0.000000
# LOCATION              0.000000
# YEAR                  0.000000
# COUNTRY               0.000000
# COMPETITION_TITLE     0.000000
# COMPETITION_DATE      0.000000
# FIRST_x               0.000000
# LAST_x                0.000000
# NATION_x              0.000000
# STARTNR               0.000000
# RANK                  0.000000
# QUALIFICATION         0.000000
# QUALIFICATION_1       0.000000
# QUALIFICATION_2       0.000000
# SEMIFINAL             0.000000
# FINAL                 0.000000
# CATEGORY              0.000000
# NAME                  0.000000
# CLIMBER_ID           13.423685
# LAST_y               13.423685
# FIRST_y              13.423685
# GENDER               13.423685
# NATION_y             13.423685
# LAST_ACTIVE          16.392385
# YOB                  13.520490
# dtype: float64

# %%
adult_boulder['GENDER'].fillna("Unknown", inplace=True)
adult_boulder['NATION_y'].fillna("Unknown", inplace=True)

# %%
adult_boulder['YOB'].fillna(0, inplace=True)
# Out:
# /Users/hpb/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
adult_boulder.drop(['CLIMBER_ID', 'LAST_y', 'FIRST_y','LAST_ACTIVE', 'PLACE'], axis=1, inplace=True)
# Out:
# /Users/hpb/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
adult_boulder.isna().mean()*100
# Out:
# COMP                 0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST_x              0.0
# LAST_x               0.0
# NATION_x             0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# CATEGORY             0.0
# NAME                 0.0
# GENDER               0.0
# NATION_y             0.0
# YOB                  0.0
# dtype: float64

# %%
adult_boulder.to_csv(r'adult_boulder.csv', index = False)

# %% [markdown]
# # Concat with lead results

# %%
youth_lead['NAME'] = youth_lead['NAME'].str.replace(" ","")
# Out:
# <ipython-input-190-0f0b0f5035a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youth_lead['NAME'] = youth_lead['NAME'].str.replace(" ","")

# %%
youth_lead.columns
# Out:
# Index(['COMP', 'PLACE', 'LOCATION', 'YEAR', 'COUNTRY', 'COMPETITION_TITLE',
#        'COMPETITION_DATE', 'FIRST', 'LAST', 'NATION', 'STARTNR', 'RANK',
#        'QUALIFICATION', 'QUALIFICATION_1', 'QUALIFICATION_2', 'SEMIFINAL',
#        'FINAL', 'POINTS', 'CATEGORY', 'NAME'],
#       dtype='object')

# %%
youth_lead.isna().mean()*100
# Out:
# COMP                 0.0
# PLACE                0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST                0.0
# LAST                 0.0
# NATION               0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# POINTS               0.0
# CATEGORY             0.0
# NAME                 0.0
# dtype: float64

# %%
youth_lead = pd.merge(youth_lead, df_ages, how='outer', on='NAME')

# %%
youth_lead.duplicated().mean()*100
# Out:
# 0.0

# %%
youth_lead.isna().mean()*100
# Out:
# COMP                 72.261224
# PLACE                72.261224
# LOCATION             72.261224
# YEAR                 72.261224
# COUNTRY              72.261224
# COMPETITION_TITLE    72.261224
# COMPETITION_DATE     72.261224
# FIRST_x              72.261224
# LAST_x               72.261224
# NATION_x             72.261224
# STARTNR              72.261224
# RANK                 72.261224
# QUALIFICATION        72.261224
# QUALIFICATION_1      72.261224
# QUALIFICATION_2      72.261224
# SEMIFINAL            72.261224
# FINAL                72.261224
# POINTS               72.261224
# CATEGORY             72.261224
# NAME                  0.000000
# CLIMBER_ID            8.636659
# LAST_y                8.636659
# FIRST_y               8.654357
# GENDER               10.117397
# NATION_y              8.636659
# LAST_ACTIVE          12.288361
# YOB                  34.056988
# dtype: float64

# %%
youth_lead = youth_lead[youth_lead['COMPETITION_TITLE'].notna()]

# %%
youth_lead['GENDER'].fillna("Unknown", inplace=True)
youth_lead['NATION_y'].fillna("Unknown", inplace=True)
youth_lead['STARTNR'].fillna(0, inplace=True)
# Out:
# /Users/hpb/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
youth_lead
# Out:
#                                 COMP               PLACE LOCATION    YEAR  \
# 0     IFSC Youth World Championships    Arco (ITA) 2019      Arco  2019.0
# 1           European Youth Cup (S,L)     Imst (AUT) 2019     Imst  2019.0
# 2     IFSC Youth World Championships   Moscow (RUS) 2018   Moscow  2018.0
# 3             European Youth Cup (L)  Munich (GER) 2018    Munich  2018.0
# 4             European Youth Cup (L)   Uster (SUI) 2018     Uster  2018.0
# ...                              ...                 ...      ...     ...
# 4697        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018.0
# 4698        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018.0
# 4699        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018.0
# 4700        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018.0
# 4701        European Youth Cup (L,S)  Voiron (FRA) 2018    Voiron  2018.0
#
#      COUNTRY                                  COMPETITION_TITLE  \
# ...

# %%
youth_lead.isna().mean()*100
# Out:
# COMP                  0.000000
# PLACE                 0.000000
# LOCATION              0.000000
# YEAR                  0.000000
# COUNTRY               0.000000
# COMPETITION_TITLE     0.000000
# COMPETITION_DATE      0.000000
# FIRST_x               0.000000
# LAST_x                0.000000
# NATION_x              0.000000
# STARTNR               0.000000
# RANK                  0.000000
# QUALIFICATION         0.000000
# QUALIFICATION_1       0.000000
# QUALIFICATION_2       0.000000
# SEMIFINAL             0.000000
# FINAL                 0.000000
# POINTS                0.000000
# CATEGORY              0.000000
# NAME                  0.000000
# CLIMBER_ID           31.135687
# LAST_y               31.135687
# FIRST_y              31.135687
# GENDER                0.000000
# NATION_y              0.000000
# LAST_ACTIVE          32.837091
# YOB                  31.135687
# dtype: float64

# %%
import random 
nans = youth_lead['YOB'].isna()
length = sum(nans)
replacement = random.choices([2002, 2003, 2004, 2000], k=length)
youth_lead.loc[nans,'YOB'] = replacement
#As you can only be between a certain age to compete in youth championships - fill nulls with average age.
# Out:
# /Users/hpb/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
youth_lead.isna().mean()*100
# Out:
# COMP                  0.000000
# PLACE                 0.000000
# LOCATION              0.000000
# YEAR                  0.000000
# COUNTRY               0.000000
# COMPETITION_TITLE     0.000000
# COMPETITION_DATE      0.000000
# FIRST_x               0.000000
# LAST_x                0.000000
# NATION_x              0.000000
# STARTNR               0.000000
# RANK                  0.000000
# QUALIFICATION         0.000000
# QUALIFICATION_1       0.000000
# QUALIFICATION_2       0.000000
# SEMIFINAL             0.000000
# FINAL                 0.000000
# POINTS                0.000000
# CATEGORY              0.000000
# NAME                  0.000000
# CLIMBER_ID           31.135687
# LAST_y               31.135687
# FIRST_y              31.135687
# GENDER                0.000000
# NATION_y              0.000000
# LAST_ACTIVE          32.837091
# YOB                   0.000000
# dtype: float64

# %%
youth_lead.drop(['CLIMBER_ID', 'LAST_y', 'FIRST_y', 'LAST_ACTIVE'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-7ed92229c425> in <module>
# ----> 1 youth_lead.drop(['CLIMBER_ID', 'LAST_y', 'FIRST_y','PLACE','LAST_ACTIVE'], axis=1, inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
youth_lead.drop(('PLACE'), axis = 1, inplace= True)
# Out:
# /Users/hpb/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
youth_lead
# Out:
#                                 COMP LOCATION    YEAR COUNTRY  \
# 0     IFSC Youth World Championships     Arco  2019.0     ITA
# 1           European Youth Cup (S,L)     Imst  2019.0     AUT
# 2     IFSC Youth World Championships   Moscow  2018.0     RUS
# 3             European Youth Cup (L)   Munich  2018.0     GER
# 4             European Youth Cup (L)    Uster  2018.0     SUI
# ...                              ...      ...     ...     ...
# 4697        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4698        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4699        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4700        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4701        European Youth Cup (L,S)   Voiron  2018.0     FRA
#
#                                       COMPETITION_TITLE  \
# 0     IFSC Youth World Championships -  Arco (ITA) 2...
# 1            European Youth Cup (S,L) - Imst (AUT) 2019
# ...

# %%
youth_lead.isna().mean()*100
# Out:
# COMP                 0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST_x              0.0
# LAST_x               0.0
# NATION_x             0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# POINTS               0.0
# CATEGORY             0.0
# NAME                 0.0
# GENDER               0.0
# NATION_y             0.0
# YOB                  0.0
# dtype: float64

# %%
youth_lead.duplicated().mean()*100
# Out:
# 0.46788600595491275

# %%
youth_lead = youth_lead.drop_duplicates()

# %%
youth_lead.reset_index(drop=True)
# Out:
#                                 COMP LOCATION    YEAR COUNTRY  \
# 0     IFSC Youth World Championships     Arco  2019.0     ITA
# 1           European Youth Cup (S,L)     Imst  2019.0     AUT
# 2     IFSC Youth World Championships   Moscow  2018.0     RUS
# 3             European Youth Cup (L)   Munich  2018.0     GER
# 4             European Youth Cup (L)    Uster  2018.0     SUI
# ...                              ...      ...     ...     ...
# 4675        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4676        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4677        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4678        European Youth Cup (L,S)   Voiron  2018.0     FRA
# 4679        European Youth Cup (L,S)   Voiron  2018.0     FRA
#
#                                       COMPETITION_TITLE  \
# 0     IFSC Youth World Championships -  Arco (ITA) 2...
# 1            European Youth Cup (S,L) - Imst (AUT) 2019
# ...

# %%
youth_lead.to_csv(r'youth_lead.csv', index = False)

# %%
adult_lead_results.columns
# Out:
# Index(['COMP', 'PLACE', 'LOCATION', 'YEAR', 'COUNTRY', 'COMPETITION_TITLE',
#        'COMPETITION_DATE', 'FIRST', 'LAST', 'NATION', 'STARTNR', 'RANK',
#        'QUALIFICATION', 'QUALIFICATION_1', 'QUALIFICATION_2', 'SEMIFINAL',
#        'FINAL', 'POINTS', 'CATEGORY', 'NAME'],
#       dtype='object')

# %%
adult_lead_results['NAME'] = adult_lead_results['NAME'].str.replace(" ","")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-225-d492fd3f644f> in <module>
# ----> 1 adult_lead_result['NAME'] = adult_lead_result['NAME'].str.replace(" ","")
#
# NameError: name 'adult_lead_result' is not defined

# %%
adult_lead = pd.merge(adult_lead_results, df_ages, how='outer', on='NAME')

# %%
adult_lead.isna().mean()*100
# Out:
# COMP                 74.488322
# PLACE                74.488322
# LOCATION             74.488322
# YEAR                 74.488322
# COUNTRY              74.488322
# COMPETITION_TITLE    74.488322
# COMPETITION_DATE     74.488322
# FIRST_x              74.488322
# LAST_x               74.488322
# NATION_x             74.488322
# STARTNR              74.488322
# RANK                 74.488322
# QUALIFICATION        74.488322
# QUALIFICATION_1      74.488322
# QUALIFICATION_2      74.488322
# SEMIFINAL            74.488322
# FINAL                74.488322
# POINTS               74.488322
# CATEGORY             74.488322
# NAME                  0.000000
# CLIMBER_ID            1.276186
# LAST_y                1.276186
# FIRST_y               1.294245
# GENDER                2.787142
# NATION_y              1.276186
# LAST_ACTIVE           5.008428
# YOB                  27.341681
# dtype: float64

# %%
adult_lead = adult_lead[adult_lead['COMPETITION_TITLE'].notna()]

# %%
adult_lead.reset_index(drop=True)
# Out:
#                                    COMP                 PLACE  LOCATION  \
# 0            IFSC Climbing Worldcup (L)     Kranj (SLO) 2019      Kranj
# 1     IFSC Climbing World Championships   Hachioji (JPN) 2019  Hachioji
# 2            IFSC Climbing Worldcup (L)  Briançon (FRA) 2019   Briançon
# 3         IFSC Climbing Worldcup (L, S)  Chamonix (FRA) 2019   Chamonix
# 4         IFSC Climbing Worldcup (L, S)    Villars (SUI) 2019   Villars
# ...                                 ...                   ...       ...
# 4233       IFSC Climbing Worldcup (L,S)   Villars (SUI) 2018    Villars
# 4234       IFSC Climbing Worldcup (L,S)   Villars (SUI) 2018    Villars
# 4235       IFSC Climbing Worldcup (L,S)   Villars (SUI) 2018    Villars
# 4236       IFSC Climbing Worldcup (L,S)   Villars (SUI) 2018    Villars
# 4237       IFSC Climbing Worldcup (L,S)   Villars (SUI) 2018    Villars
#
#         YEAR COUNTRY                                  COMPETITION_TITLE  \
# ...

# %%
adult_lead.isna().mean()*100
# Out:
# COMP                 0.000000
# PLACE                0.000000
# LOCATION             0.000000
# YEAR                 0.000000
# COUNTRY              0.000000
# COMPETITION_TITLE    0.000000
# COMPETITION_DATE     0.000000
# FIRST_x              0.000000
# LAST_x               0.000000
# NATION_x             0.000000
# STARTNR              0.000000
# RANK                 0.000000
# QUALIFICATION        0.000000
# QUALIFICATION_1      0.000000
# QUALIFICATION_2      0.000000
# SEMIFINAL            0.000000
# FINAL                0.000000
# POINTS               0.000000
# CATEGORY             0.000000
# NAME                 0.000000
# CLIMBER_ID           5.002360
# LAST_y               5.002360
# FIRST_y              5.002360
# GENDER               5.002360
# NATION_y             5.002360
# LAST_ACTIVE          6.701274
# YOB                  5.521472
# dtype: float64

# %%
adult_lead['GENDER'].fillna("Unknown", inplace=True)
adult_lead['NATION_y'].fillna("Unknown", inplace=True)

# %%
adult_lead['YOB'].fillna(0, inplace=True)

# %%
adult_lead.isna().mean()*100
# Out:
# COMP                 0.000000
# PLACE                0.000000
# LOCATION             0.000000
# YEAR                 0.000000
# COUNTRY              0.000000
# COMPETITION_TITLE    0.000000
# COMPETITION_DATE     0.000000
# FIRST_x              0.000000
# LAST_x               0.000000
# NATION_x             0.000000
# STARTNR              0.000000
# RANK                 0.000000
# QUALIFICATION        0.000000
# QUALIFICATION_1      0.000000
# QUALIFICATION_2      0.000000
# SEMIFINAL            0.000000
# FINAL                0.000000
# POINTS               0.000000
# CATEGORY             0.000000
# NAME                 0.000000
# CLIMBER_ID           5.002360
# LAST_y               5.002360
# FIRST_y              5.002360
# GENDER               0.000000
# NATION_y             0.000000
# LAST_ACTIVE          6.701274
# YOB                  0.000000
# dtype: float64

# %%
adult_lead.duplicated().mean()*100
# Out:
# 0.0

# %%
adult_lead.drop(['CLIMBER_ID', 'LAST_y', 'FIRST_y','LAST_ACTIVE', 'PLACE'], axis=1, inplace=True)

# %%
adult_lead.isna().mean()*100
# Out:
# COMP                 0.0
# LOCATION             0.0
# YEAR                 0.0
# COUNTRY              0.0
# COMPETITION_TITLE    0.0
# COMPETITION_DATE     0.0
# FIRST_x              0.0
# LAST_x               0.0
# NATION_x             0.0
# STARTNR              0.0
# RANK                 0.0
# QUALIFICATION        0.0
# QUALIFICATION_1      0.0
# QUALIFICATION_2      0.0
# SEMIFINAL            0.0
# FINAL                0.0
# POINTS               0.0
# CATEGORY             0.0
# NAME                 0.0
# GENDER               0.0
# NATION_y             0.0
# YOB                  0.0
# dtype: float64

# %%
adult_lead.to_csv(r'adult_lead.csv', index = False)
